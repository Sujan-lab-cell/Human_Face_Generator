# %%
# !git config --global user.name "Sujan-lab-cell"
# !git config --global user.email "sujankswork@gmail.com"

# %%
# !git add .

# !git commit -m "Updated training"

# !git pull origin main --rebase

# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# From https://github.com/sujan-lab-cell/Human_Face_Generator
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Everything up-to-date

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !git add .
# !git commit -m "Updated training"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/sujan-lab-cell/Human_Face_Generator.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/sujan-lab-cell/Human_Face_Generator.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# !git push
# Out:
# Everything up-to-date

# %%
# !cp /kaggle/working/*.ipynb /kaggle/working/Human_Face_Generator/

# %cd /kaggle/working/Human_Face_Generator

# !git add .
# !git commit -m "Updated notebook"
# !git push
# Out:
# cp: cannot stat '/kaggle/working/*.ipynb': No such file or directory
# /kaggle/working/Human_Face_Generator
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/sujan-lab-cell/Human_Face_Generator.git/'

# %%
import os

dataset_path = "/kaggle/input/datasets/sujanksgowdas/train-image/student_photos"

images = os.listdir(dataset_path)

print("Total Images:", len(images))
print(images[:5])
# Out:
# Total Images: 2638
# ['NNM24RI008.JPG', 'NNM24IS248.JPG', 'NNM23BT011.JPG', 'NNM24EE013.JPG', 'NNM23EC199.JPG']
